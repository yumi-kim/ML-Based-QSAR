# %%
'''
## 2019. 3. 11
## updated by 2019. 5.30
## updated by 2019. 9.09
## updated by 2019. 10.30
## updated by 2019. 11.4 Updated about Parameters

by Yumi Kim CBBL at GNU
To Optimize Using Univariate feature selection
Univariate feature selection works 
by selecting the best features based on univariate statistical tests. 
It can be seen as a preprocessing step to an estimator.

'''

# import Libraries
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# Parameters
after_hcf_file_name = 'train_x_removing_high_correlation_feature_values.csv'
select_k_value = 15 # Recomand Under 20 or 15
output_file_name = 'train_x_univariate_feature_selection_f_regression.csv'

# Read from csv file
raw_dataset = pd.read_csv(after_hcf_file_name)

if 'smile' in raw_dataset.columns:
    smile_data = raw_dataset['smile'] 
    raw_dataset = raw_dataset.drop("smile", axis = 1) # Remove "SMILE" column
    
# Get Data and Target from raw_dataset
y_IC50_data = []  
if 'IC50' in raw_dataset.columns:
    y_IC50_data = raw_dataset['IC50'] 
    #print(smile_data)
    raw_dataset = raw_dataset.drop("IC50", axis = 1) # Remove "IC50" column
    
##### Machine Learning Algorithm
##### Univariate Feature Selection(UFS)
X = raw_dataset
X.shape
y = y_IC50_data

#For Debug
print(raw_dataset.info())

sel = SelectKBest(f_regression, k=select_k_value)
sel_data= sel.fit_transform(X,y)
X_selected_df = pd.DataFrame(sel_data, columns=[raw_dataset.columns[i] for i in range(len(raw_dataset.columns)) if sel.get_support()[i]])

# To write for Univariate Feature Selection(UFS)
print("============================================")
print("After Processing of Univariate Feature Selection(UFS)")
print("============================================")
print(X_selected_df.info())
X_selected_df['smile']=smile_data # appending for removed "SMILE" column
X_selected_df['IC50']=y_IC50_data # appending for removed "IC50" column
X_selected_df.to_csv(output_file_name, index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Columns: 128 entries, ALogP to XLogP
# dtypes: float64(128)
# memory usage: 15.1 KB
# None
# ============================================
# After Processing of Univariate Feature Selection(UFS)
# ============================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 15 columns):
# ALogP                15 non-null float64
# AATS3m               15 non-null float64
# AATS4m               15 non-null float64
# AATS3v               15 non-null float64
# AATS4v               15 non-null float64
# ATSC3i               15 non-null float64
# C1SP3                15 non-null float64
# VE3_Dt               15 non-null float64
# nHaaCH               15 non-null float64
# SaaCH                15 non-null float64
# LipoaffinityIndex    15 non-null float64
# DELS2                15 non-null float64
# ETA_dBeta            15 non-null float64
# WTPT-3               15 non-null float64
# XLogP                15 non-null float64
# dtypes: float64(15)
# memory usage: 1.8 KB
# None
